# %%
pip install pandas numpy matplotlib seaborn scikit-learn
# Out:
# Requirement already satisfied: pandas in c:\users\shubh\onedrive\desktop\end-to-end-ml-pipeline-project\myvenv\lib\site-packages (3.0.2)
# Requirement already satisfied: numpy in c:\users\shubh\onedrive\desktop\end-to-end-ml-pipeline-project\myvenv\lib\site-packages (2.4.4)
# Requirement already satisfied: matplotlib in c:\users\shubh\onedrive\desktop\end-to-end-ml-pipeline-project\myvenv\lib\site-packages (3.10.8)
# Requirement already satisfied: seaborn in c:\users\shubh\onedrive\desktop\end-to-end-ml-pipeline-project\myvenv\lib\site-packages (0.13.2)
# Requirement already satisfied: scikit-learn in c:\users\shubh\onedrive\desktop\end-to-end-ml-pipeline-project\myvenv\lib\site-packages (1.8.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\shubh\onedrive\desktop\end-to-end-ml-pipeline-project\myvenv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\shubh\onedrive\desktop\end-to-end-ml-pipeline-project\myvenv\lib\site-packages (from pandas) (2026.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\shubh\onedrive\desktop\end-to-end-ml-pipeline-project\myvenv\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\shubh\onedrive\desktop\end-to-end-ml-pipeline-project\myvenv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\shubh\onedrive\desktop\end-to-end-ml-pipeline-project\myvenv\lib\site-packages (from matplotlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\shubh\onedrive\desktop\end-to-end-ml-pipeline-project\myvenv\lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\shubh\onedrive\desktop\end-to-end-ml-pipeline-project\myvenv\lib\site-packages (from matplotlib) (26.1)
# Requirement already satisfied: pillow>=8 in c:\users\shubh\onedrive\desktop\end-to-end-ml-pipeline-project\myvenv\lib\site-packages (from matplotlib) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\shubh\onedrive\desktop\end-to-end-ml-pipeline-project\myvenv\lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: scipy>=1.10.0 in c:\users\shubh\onedrive\desktop\end-to-end-ml-pipeline-project\myvenv\lib\site-packages (from scikit-learn) (1.17.1)
# Requirement already satisfied: joblib>=1.3.0 in c:\users\shubh\onedrive\desktop\end-to-end-ml-pipeline-project\myvenv\lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\shubh\onedrive\desktop\end-to-end-ml-pipeline-project\myvenv\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: six>=1.5 in c:\users\shubh\onedrive\desktop\end-to-end-ml-pipeline-project\myvenv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install xgboost
# Out:
# Requirement already satisfied: xgboost in c:\users\shubh\onedrive\desktop\end-to-end-ml-pipeline-project\myvenv\lib\site-packages (3.2.0)
# Requirement already satisfied: numpy in c:\users\shubh\onedrive\desktop\end-to-end-ml-pipeline-project\myvenv\lib\site-packages (from xgboost) (2.4.4)
# Requirement already satisfied: scipy in c:\users\shubh\onedrive\desktop\end-to-end-ml-pipeline-project\myvenv\lib\site-packages (from xgboost) (1.17.1)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv('data\\Telco_Customer_Churn.csv')

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
# 2          No          No              No  Month-to-month              Yes
# 3         Yes          No              No        One year               No
# 4          No          No              No  Month-to-month              Yes
#
#                PaymentMethod MonthlyCharges  TotalCharges Churn
# 0           Electronic check          29.85         29.85    No
# 1               Mailed check          56.95        1889.5    No
# 2               Mailed check          53.85        108.15   Yes
# 3  Bank transfer (automatic)          42.30       1840.75    No
# 4           Electronic check          70.70        151.65   Yes
#
# [5 rows x 21 columns]

# %%
df.shape
# Out:
# (7043, 21)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   str
#  1   gender            7043 non-null   str
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   str
#  4   Dependents        7043 non-null   str
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   str
#  7   MultipleLines     7043 non-null   str
#  8   InternetService   7043 non-null   str
#  9   OnlineSecurity    7043 non-null   str
#  10  OnlineBackup      7043 non-null   str
#  11  DeviceProtection  7043 non-null   str
#  12  TechSupport       7043 non-null   str
#  13  StreamingTV       7043 non-null   str
#  14  StreamingMovies   7043 non-null   str
#  15  Contract          7043 non-null   str
#  16  PaperlessBilling  7043 non-null   str
#  17  PaymentMethod     7043 non-null   str
#  18  MonthlyCharges    7043 non-null   float64
#  19  TotalCharges      7043 non-null   str
#  20  Churn             7043 non-null   str
# dtypes: float64(1), int64(2), str(18)
# memory usage: 1.1 MB

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'], errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   str
#  1   gender            7043 non-null   str
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   str
#  4   Dependents        7043 non-null   str
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   str
#  7   MultipleLines     7043 non-null   str
#  8   InternetService   7043 non-null   str
#  9   OnlineSecurity    7043 non-null   str
#  10  OnlineBackup      7043 non-null   str
#  11  DeviceProtection  7043 non-null   str
#  12  TechSupport       7043 non-null   str
#  13  StreamingTV       7043 non-null   str
#  14  StreamingMovies   7043 non-null   str
#  15  Contract          7043 non-null   str
#  16  PaperlessBilling  7043 non-null   str
#  17  PaymentMethod     7043 non-null   str
#  18  MonthlyCharges    7043 non-null   float64
#  19  TotalCharges      7032 non-null   float64
#  20  Churn             7043 non-null   str
# dtypes: float64(2), int64(2), str(17)
# memory usage: 1.1 MB

# %%
df.isna().sum()
# Out:
# customerID           0
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %%
df = df.dropna(subset=['TotalCharges'])

# %%
len(df['TotalCharges'])
# Out:
# 7032

# %%
df.isna().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df.shape
# Out:
# (7032, 21)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges
# count    7032.000000  7032.000000     7032.000000   7032.000000
# mean        0.162400    32.421786       64.798208   2283.300441
# std         0.368844    24.545260       30.085974   2266.771362
# min         0.000000     1.000000       18.250000     18.800000
# 25%         0.000000     9.000000       35.587500    401.450000
# 50%         0.000000    29.000000       70.350000   1397.475000
# 75%         0.000000    55.000000       89.862500   3794.737500
# max         1.000000    72.000000      118.750000   8684.800000

# %%
df.drop(columns=['customerID'], inplace=True)

# %%
df.columns
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure',
#        'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity',
#        'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV',
#        'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod',
#        'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='str')

# %%
numerical_features = ['tenure','MonthlyCharges','TotalCharges']
categorical_features = ['gender', 'SeniorCitizen', 'Partner', 'Dependents',
       'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity',
       'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV',
       'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod',]

# %%
X = df[numerical_features + categorical_features]
y = df['Churn']

# %%
X
# Out:
#       tenure  MonthlyCharges  TotalCharges  gender  SeniorCitizen Partner  \
# 0          1           29.85         29.85  Female              0     Yes
# 1         34           56.95       1889.50    Male              0      No
# 2          2           53.85        108.15    Male              0      No
# 3         45           42.30       1840.75    Male              0      No
# 4          2           70.70        151.65  Female              0      No
# ...      ...             ...           ...     ...            ...     ...
# 7038      24           84.80       1990.50    Male              0     Yes
# 7039      72          103.20       7362.90  Female              0     Yes
# 7040      11           29.60        346.45  Female              0     Yes
# 7041       4           74.40        306.60    Male              1     Yes
# 7042      66          105.65       6844.50    Male              0      No
#
#      Dependents PhoneService     MultipleLines InternetService OnlineSecurity  \
# 0            No           No  No phone service             DSL             No
# 1            No          Yes                No             DSL            Yes
# 2            No          Yes                No             DSL            Yes
# 3            No           No  No phone service             DSL            Yes
# 4            No          Yes                No     Fiber optic             No
# ...         ...          ...               ...             ...            ...
# 7038        Yes          Yes               Yes             DSL            Yes
# 7039        Yes          Yes               Yes     Fiber optic             No
# 7040        Yes           No  No phone service             DSL            Yes
# 7041         No          Yes               Yes     Fiber optic             No
# 7042         No          Yes                No     Fiber optic            Yes
#
#      OnlineBackup DeviceProtection TechSupport StreamingTV StreamingMovies  \
# 0             Yes               No          No          No              No
# 1              No              Yes          No          No              No
# 2             Yes               No          No          No              No
# 3              No              Yes         Yes          No              No
# 4              No               No          No          No              No
# ...           ...              ...         ...         ...             ...
# 7038           No              Yes         Yes         Yes             Yes
# 7039          Yes              Yes          No         Yes             Yes
# 7040           No               No          No          No              No
# 7041           No               No          No          No              No
# 7042           No              Yes         Yes         Yes             Yes
#
#             Contract PaperlessBilling              PaymentMethod
# 0     Month-to-month              Yes           Electronic check
# 1           One year               No               Mailed check
# 2     Month-to-month              Yes               Mailed check
# 3           One year               No  Bank transfer (automatic)
# 4     Month-to-month              Yes           Electronic check
# ...              ...              ...                        ...
# 7038        One year              Yes               Mailed check
# 7039        One year              Yes    Credit card (automatic)
# 7040  Month-to-month              Yes           Electronic check
# 7041  Month-to-month              Yes               Mailed check
# 7042        Two year              Yes  Bank transfer (automatic)
#
# [7032 rows x 19 columns]

# %%
y.value_counts()
# Out:
# Churn
# No     5163
# Yes    1869
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, stratify=y)

# %%
y_train = y_train.map({"No":0, "Yes":1})
y_test = y_test.map({"No":0, "Yes":1})
y = y.map({"No":0, "Yes":1})

# %%
y_test
# Out:
# 3870    0
# 1289    0
# 4745    0
# 4777    0
# 4726    0
#        ..
# 3914    0
# 6912    0
# 3311    0
# 832     0
# 1555    1
# Name: Churn, Length: 2110, dtype: int64

# %%
print(np.round(y.mean(), 3))
print(np.round(y_test.mean(), 3))
print(np.round(y_train.mean(), 3))
# Out:
# 0.266
# 0.266
# 0.266

# %%
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, StandardScaler

cat_pipeline = Pipeline(steps=[
  ('imputer', SimpleImputer(strategy='most_frequent')),
  ('ohe', OneHotEncoder(handle_unknown='ignore'))
])

num_pipeline = Pipeline(steps=[
  ('imputer', SimpleImputer(strategy='median')),
  ('scaler', StandardScaler())
])

# %%
preprocesser = ColumnTransformer(
  transformers=[
    ('num', num_pipeline, numerical_features),
    ('cat', cat_pipeline, categorical_features)
  ], remainder='drop'
)

# %%
from sklearn.linear_model import LogisticRegression

lr_pipeline = Pipeline(steps=[
  ('preprocessing', preprocesser),
  ('lr_classifier', LogisticRegression(class_weight='balanced', random_state=42))
])

# %%
lr_pipeline.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('preprocessing',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['tenure', 'MonthlyCharges',
#                                                    'TotalCharges']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('ohe',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['gender', 'SeniorCitizen',
#                                                    'Partner', 'Dependents',
#                                                    'PhoneService',
#                                                    'MultipleLines',
#                                                    'InternetService',
#                                                    'OnlineSecurity',
#                                                    'OnlineBackup',
#                                                    'DeviceProtection',
#                                                    'TechSupport', 'StreamingTV',
#                                                    'StreamingMovies',
#                                                    'Contract',
#                                                    'PaperlessBilling',
#                                                    'PaymentMethod'])])),
#                 ('lr_classifier',
#                  LogisticRegression(class_weight='balanced', random_state=42))])

# %%
y_pred = lr_pipeline.predict(X_test)

# %%
y_prob = lr_pipeline.predict_proba(X_test)[:, 1]

# %%
from sklearn.metrics import accuracy_score,confusion_matrix, precision_score, recall_score, f1_score, r2_score

accuracy = accuracy_score(y_test, y_pred=y_pred)
recall = recall_score(y_test, y_pred=y_pred)
r2 = r2_score(y_test, y_pred=y_pred)
f1 = f1_score(y_test, y_pred=y_pred)
precision = precision_score(y_test, y_pred=y_pred)

print(f'accuracy:{accuracy}\n precision:{precision}\n recall:{recall}\n f1:{f1}\n r2:{r2}\n ')
# Out:
# accuracy:0.7445497630331753
#  precision:0.512249443207127
#  recall:0.8199643493761141
#  f1:0.630568882796436
#  r2:-0.30875074368029987

# %%
print(confusion_matrix(y_test, y_pred))
# Out:
# [[1111  438]
#  [ 101  460]]

# %%
from sklearn.metrics import classification_report, roc_curve, auc
classification_report(y_test, y_pred)
# Out:
# '              precision    recall  f1-score   support\n\n           0       0.92      0.72      0.80      1549\n           1       0.51      0.82      0.63       561\n\n    accuracy                           0.74      2110\n   macro avg       0.71      0.77      0.72      2110\nweighted avg       0.81      0.74      0.76      2110\n'

# %%
fpr, tpr, thresholds = roc_curve(y_test, y_prob)
roc_auc = auc(fpr, tpr)
print(roc_auc)
# Out:
# 0.8563457074830635

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc:.2f})')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc="lower right")
plt.grid(alpha=0.3)
plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf_model = Pipeline(steps=[
    ('preprocessor', preprocesser),
    ('model', RandomForestClassifier(
        n_estimators = 200,
        class_weight = 'balanced',
        random_state = 42,

    ))
])

# %%
rf_model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['tenure', 'MonthlyCharges',
#                                                    'TotalCharges']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('ohe',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['gender', 'SeniorCitizen',
#                                                    'Partner', 'Dependents',
#                                                    'PhoneService',
#                                                    'MultipleLines',
#                                                    'InternetService',
#                                                    'OnlineSecurity',
#                                                    'OnlineBackup',
#                                                    'DeviceProtection',
#                                                    'TechSupport', 'StreamingTV',
#                                                    'StreamingMovies',
#                                                    'Contract',
#                                                    'PaperlessBilling',
#                                                    'PaymentMethod'])])),
#                 ('model',
#                  RandomForestClassifier(class_weight='balanced',
#                                         n_estimators=200, random_state=42))])

# %%
y_pred_rf = rf_model.predict(X_test)

# %%
y_prob_rf = rf_model.predict_proba(X_test)[:, 1]

# %%
recall_score(y_test, y_pred_rf)
# Out:
# 0.768270944741533

# %%
print(classification_report(y_test, y_pred_rf))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.90      0.86      1549
#            1       0.63      0.47      0.54       561
#
#     accuracy                           0.79      2110
#    macro avg       0.73      0.68      0.70      2110
# weighted avg       0.77      0.79      0.77      2110

# %%
print(confusion_matrix(y_test, y_pred_rf))
# Out:
# [[1397  152]
#  [ 299  262]]

# %%
fpr_rf, tpr_rf, thresholds_rf = roc_curve(y_test, y_prob_rf)
roc_auc_rf = auc(fpr_rf, tpr_rf)
print(roc_auc_rf)
# Out:
# 0.826047855611521

# %%
plt.figure(figsize=(8, 6))
plt.plot(fpr_rf, tpr_rf, color='darkorange', lw=2, label=f"Random Forest (AUC = {roc_auc_rf:.2f})")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve - Random Forest")
plt.legend(loc="lower right")
plt.grid(alpha=0.3)
plt.show()

# %%
from sklearn.model_selection import cross_val_score

cv_auc = cross_val_score(
    lr_pipeline, X_train, y_train,
    scoring='roc_auc',
    cv=5
)
print("Logistic Regression CV AUC:", cv_auc.mean())
# Out:
# Logistic Regression CV AUC: 0.839267833285264

# %%
cv_auc = cross_val_score(
    rf_model, X_train, y_train,
    scoring='roc_auc',
    cv=5
)
print("Random Forest CV AUC:", cv_auc.mean())
# Out:
# Random Forest CV AUC: 0.8182144595688833

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    'model__n_estimators': [200, 400],
    'model__max_depth': [None, 10, 20],
    'model__min_samples_split': [2, 10],
    'model__min_samples_leaf': [1, 5]
}

# %%
grid_rf = GridSearchCV(
    rf_model,
    param_grid,
    scoring='roc_auc',
    cv=3,
    n_jobs=-1,
    verbose=2
)

grid_rf.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 24 candidates, totalling 72 fits
# GridSearchCV(cv=3,
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('num',
#                                                                          Pipeline(steps=[('imputer',
#                                                                                           SimpleImputer(strategy='median')),
#                                                                                          ('scaler',
#                                                                                           StandardScaler())]),
#                                                                          ['tenure',
#                                                                           'MonthlyCharges',
#                                                                           'TotalCharges']),
#                                                                         ('cat',
#                                                                          Pipeline(steps=[('imputer',
#                                                                                           SimpleImputer(strategy='most_frequent')),
#                                                                                          ('ohe',
#                                                                                           OneHotEncoder(handle_unknown='igno...
#                                                                           'StreamingTV',
#                                                                           'StreamingMovies',
#                                                                           'Contract',
#                                                                           'PaperlessBilling',
#                                                                           'PaymentMethod'])])),
#                                        ('model',
#                                         RandomForestClassifier(class_weight='balanced',
#                                                                n_estimators=200,
#                                                                random_state=42))]),
#              n_jobs=-1,
#              param_grid={'model__max_depth': [None, 10, 20],
#                          'model__min_samples_leaf': [1, 5],
#                          'model__min_samples_split': [2, 10],
#                          'model__n_estimators': [200, 400]},
#              scoring='roc_auc', verbose=2)

# %%
print("Best RF Params:", grid_rf.best_params_)
print("Best RF CV AUC:", grid_rf.best_score_)
# Out:
# Best RF Params: {'model__max_depth': 10, 'model__min_samples_leaf': 5, 'model__min_samples_split': 2, 'model__n_estimators': 400}
# Best RF CV AUC: 0.8385606218598639

# %%
best_rf = grid_rf.best_estimator_

y_pred_rf = best_rf.predict(X_test)
y_pred_proba_rf = best_rf.predict_proba(X_test)[:, 1]

fpr_rf, tpr_rf, thresholds_rf = roc_curve(y_test, y_pred_proba_rf)
roc_auc_rf = auc(fpr_rf, tpr_rf)
print(roc_auc_rf)
print(recall_score(y_test, y_pred_rf))
print(classification_report(y_test, y_pred_rf))
# Out:
# 0.8560165893929612
# 0.768270944741533
#               precision    recall  f1-score   support
#
#            0       0.90      0.78      0.84      1549
#            1       0.56      0.77      0.64       561
#
#     accuracy                           0.77      2110
#    macro avg       0.73      0.77      0.74      2110
# weighted avg       0.81      0.77      0.78      2110

# %%
feature_names = best_rf.named_steps['preprocessor'].get_feature_names_out()
importances = best_rf.named_steps['model'].feature_importances_

feat_imp = pd.DataFrame({
    'feature': feature_names,
    'importance': importances
}).sort_values(by='importance', ascending=False)

feat_imp.head(15)
# Out:
#                                 feature  importance
# 0                           num__tenure    0.125641
# 37         cat__Contract_Month-to-month    0.122152
# 2                     num__TotalCharges    0.105613
# 19               cat__OnlineSecurity_No    0.068073
# 1                   num__MonthlyCharges    0.067230
# 39               cat__Contract_Two year    0.060533
# 28                  cat__TechSupport_No    0.045242
# 17     cat__InternetService_Fiber optic    0.039841
# 44  cat__PaymentMethod_Electronic check    0.035088
# 21              cat__OnlineSecurity_Yes    0.022044
# 38               cat__Contract_One year    0.019158
# 16             cat__InternetService_DSL    0.016922
# 22                 cat__OnlineBackup_No    0.015590
# 25             cat__DeviceProtection_No    0.013049
# 30                 cat__TechSupport_Yes    0.011601

# %%
top_features = feat_imp.head(15)
plt.figure(figsize=(10, 6))
plt.barh(top_features['feature'], top_features['importance'])
plt.gca().invert_yaxis()
plt.title("Top Drivers of Customer Churn")
plt.show()

# %%
thresholds = np.arange(0.1, 0.9, 0.05)

results = []

for t in thresholds:
    y_pred_custom = (y_pred_proba_rf >= t).astype(int)

    precision = precision_score(y_test, y_pred_custom)
    recall = recall_score(y_test, y_pred_custom)
    f1 = f1_score(y_test, y_pred_custom)

    results.append((t, precision, recall, f1))

results_df = pd.DataFrame(results, columns=["threshold", "precision", "recall", "f1"])
results_df
# Out:
#     threshold  precision    recall        f1
# 0        0.10   0.343052  0.985740  0.508974
# 1        0.15   0.371717  0.983957  0.539589
# 2        0.20   0.393407  0.957219  0.557632
# 3        0.25   0.420290  0.930481  0.579035
# 4        0.30   0.445510  0.910873  0.598361
# 5        0.35   0.473934  0.891266  0.618812
# 6        0.40   0.495825  0.846702  0.625411
# 7        0.45   0.530374  0.809269  0.640790
# 8        0.50   0.555412  0.768271  0.644727
# 9        0.55   0.582242  0.713012  0.641026
# 10       0.60   0.617347  0.647059  0.631854
# 11       0.65   0.645098  0.586453  0.614379
# 12       0.70   0.680460  0.527629  0.594378
# 13       0.75   0.750000  0.422460  0.540479
# 14       0.80   0.803109  0.276292  0.411141
# 15       0.85   0.883333  0.188948  0.311307

# %%
plt.figure(figsize=(8,5))
plt.plot(results_df["threshold"], results_df["precision"], label="Precision")
plt.plot(results_df["threshold"], results_df["recall"], label="Recall")
plt.plot(results_df["threshold"], results_df["f1"], label="F1 Score")
plt.xlabel("Threshold")
plt.ylabel("Score")
plt.legend()
plt.title("Precision-Recall Tradeoff by Threshold")
plt.grid(alpha=0.3)
plt.show()

# %%
import seaborn as sns
y_pred_final = best_rf.predict(X_test)

cm = confusion_matrix(y_test, y_pred_final)

plt.figure(figsize=(6,4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix - Final Model")
plt.show()

# %%
plt.figure(figsize=(8,6))

plt.plot(fpr, tpr, label=f"Logistic Regression (AUC={roc_auc:.2f})")
plt.plot(fpr_rf, tpr_rf, label=f"Random Forest (AUC={roc_auc_rf:.2f})")

plt.plot([0,1],[0,1],'k--')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Model Comparison ROC Curve")
plt.legend()
plt.show()

# %%
neg, pos = np.bincount(y_train)
scale_pos_weight = neg / pos

# %%
from xgboost import XGBClassifier

xgb_model = Pipeline(steps=[
    ('preprocessor', preprocesser),
    ('model', XGBClassifier(
        n_estimators=200,
        learning_rate=0.05,
        max_depth=4,
        subsample=0.8,
        colsample_bytree=0.8,
        scale_pos_weight=scale_pos_weight,
        random_state=42,
        eval_metric='logloss'
    ))
])

# %%
xgb_model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['tenure', 'MonthlyCharges',
#                                                    'TotalCharges']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('ohe',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['gender', 'SeniorCit...
#                                feature_types=None, feature_weights=None,
#                                gamma=None, grow_policy=None,
#                                importance_type=None,
#                                interaction_constraints=None, learning_rate=0.05,
#                                max_bin=None, max_cat_threshold=None,
#                                max_cat_to_onehot=None, max_delta_step=None,
#                                max_depth=4, max_leaves=None,
#                                min_child_weight=None, missing=nan,
#                                monotone_constraints=None, multi_strategy=None,
#                                n_estimators=200, n_jobs=None,
#                                num_parallel_tree=None, ...))])

# %%
from sklearn.metrics import roc_auc_score

y_pred_xgb = xgb_model.predict(X_test)
y_proba_xgb = xgb_model.predict_proba(X_test)[:, 1]

print(classification_report(y_test, y_pred_xgb))
print("ROC AUC:", roc_auc_score(y_test, y_proba_xgb))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.74      0.82      1549
#            1       0.53      0.81      0.64       561
#
#     accuracy                           0.76      2110
#    macro avg       0.72      0.78      0.73      2110
# weighted avg       0.81      0.76      0.77      2110
#
# ROC AUC: 0.8541937815093172

# %%
performance_df = pd.DataFrame({
    "Model": ["Logistic Regression", "Random Forest", "XGBoost"],
    "ROC AUC": [0.86, 0.85, round(roc_auc_score(y_test, y_proba_xgb), 2)],
    "F1 Score": [0.64, 0.65, round(f1_score(y_test, y_pred_xgb), 2)],
    "Precision": [0.52, 0.56, round(precision_score(y_test, y_pred_xgb), 2)],
    "Recall": [0.84, 0.78, round(recall_score(y_test, y_pred_xgb), 2)]
})
performance_df
# Out:
#                  Model  ROC AUC  F1 Score  Precision  Recall
# 0  Logistic Regression     0.86      0.64       0.52    0.84
# 1        Random Forest     0.85      0.65       0.56    0.78
# 2              XGBoost     0.85      0.64       0.53    0.81
